# %% [markdown]
# # 지도 시각화

# %%
#!pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\tjoeun\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\tjoeun\anaconda3\lib\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\tjoeun\anaconda3\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\tjoeun\anaconda3\lib\site-packages (from folium) (2.3.5)
# Requirement already satisfied: requests in c:\users\tjoeun\anaconda3\lib\site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\tjoeun\anaconda3\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tjoeun\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tjoeun\anaconda3\lib\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tjoeun\anaconda3\lib\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tjoeun\anaconda3\lib\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tjoeun\anaconda3\lib\site-packages (from requests->folium) (2025.11.12)

# %% [markdown]
# ### 기본 지도 그리기

# %%
import folium

m = folium.Map(
    location=[37.566826, 126.9786567],
    zoom_start=11
)

m.save('data/map_basic.html')
print('지도 저장 완료: data/map_basic.html')
m
# Out:
# 지도 저장 완료: data/map_basic.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b53544f5da3502921ea520f3337515a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b53544f5da3502921ea520f3337515a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b53544f5da3502921ea520f3337515a6 = L.map(
#                 &quot;map_b53544f5da3502921ea520f3337515a6&quot;,
#                 {
#                     center: [37.566826, 126.9786567],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57548b873d670d44ad63430c0294ac37 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57548b873d670d44ad63430c0294ac37.addTo(map_b53544f5da3502921ea520f3337515a6);
#
#
#             tile_layer_57548b873d670d44ad63430c0294ac37.addTo(map_b53544f5da3502921ea520f3337515a6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 마커 + 팝업 + 툴팁

# %%
locations = [
    {'name': '경복궁', 'lat': 37.5796, 'lon': 126.9770, 'desc': '조선의 법궁'},
    {'name': '남산타워', 'lat': 37.5512, 'lon': 126.9882, 'desc': 'N서울타워'},
    {'name': '인사동', 'lat': 37.5741, 'lon': 126.9862, 'desc': '전통문화거리'},
]

m2 = folium.Map(location=[37.566, 126.977], zoom_start=13)

for loc in locations:
    folium.Marker(
        location=[loc['lat'], loc['lon']],
        popup=folium.Popup(f"<b>{loc['name']}</b><br>{loc['desc']}", max_width=200),
        tooltip=loc['name'],
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m2)

m2.save('data/map_markers.html')
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04dfce029b9aed062c2243e588fe682b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04dfce029b9aed062c2243e588fe682b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04dfce029b9aed062c2243e588fe682b = L.map(
#                 &quot;map_04dfce029b9aed062c2243e588fe682b&quot;,
#                 {
#                     center: [37.566, 126.977],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b610ddc842782e72616114cbd1312c28 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b610ddc842782e72616114cbd1312c28.addTo(map_04dfce029b9aed062c2243e588fe682b);
#
#
#             var marker_96cc2170a2b48f492f5aafca8f6fefd9 = L.marker(
#                 [37.5796, 126.977],
#                 {
# }
#             ).addTo(map_04dfce029b9aed062c2243e588fe682b);
#
#
#             var icon_70a1bffe1af1f1b14ee38d8a1ad69458 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d97b70f68be9946e250623a34737cb82 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_1b36b4de82585ec1050501cedcb6d65f = $(`&lt;div id=&quot;html_1b36b4de82585ec1050501cedcb6d65f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;경복궁&lt;/b&gt;&lt;br&gt;조선의 법궁&lt;/div&gt;`)[0];
#                 popup_d97b70f68be9946e250623a34737cb82.setContent(html_1b36b4de82585ec1050501cedcb6d65f);
#
#
#
#         marker_96cc2170a2b48f492f5aafca8f6fefd9.bindPopup(popup_d97b70f68be9946e250623a34737cb82)
#         ;
#
#
#
#
#             marker_96cc2170a2b48f492f5aafca8f6fefd9.bindTooltip(
#                 `&lt;div&gt;
#                      경복궁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_96cc2170a2b48f492f5aafca8f6fefd9.setIcon(icon_70a1bffe1af1f1b14ee38d8a1ad69458);
#
#
#             var marker_84626616b5ec8a0f81ea046aa19655f0 = L.marker(
#                 [37.5512, 126.9882],
#                 {
# }
#             ).addTo(map_04dfce029b9aed062c2243e588fe682b);
#
#
#             var icon_5a731359cf896fc658ec1a83444b6033 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_83d3c9bb920c4773c9208b1951c7070a = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_b413a280db9fd9ce52c438ab9a1e63bc = $(`&lt;div id=&quot;html_b413a280db9fd9ce52c438ab9a1e63bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;남산타워&lt;/b&gt;&lt;br&gt;N서울타워&lt;/div&gt;`)[0];
#                 popup_83d3c9bb920c4773c9208b1951c7070a.setContent(html_b413a280db9fd9ce52c438ab9a1e63bc);
#
#
#
#         marker_84626616b5ec8a0f81ea046aa19655f0.bindPopup(popup_83d3c9bb920c4773c9208b1951c7070a)
#         ;
#
#
#
#
#             marker_84626616b5ec8a0f81ea046aa19655f0.bindTooltip(
#                 `&lt;div&gt;
#                      남산타워
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_84626616b5ec8a0f81ea046aa19655f0.setIcon(icon_5a731359cf896fc658ec1a83444b6033);
#
#
#             var marker_ad562c9f88bc687440501d42b2d5d608 = L.marker(
#                 [37.5741, 126.9862],
#                 {
# }
#             ).addTo(map_04dfce029b9aed062c2243e588fe682b);
#
#
#             var icon_0a45bb2ab1af12f67d2124798016658a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c6d92aeb1683975c7f095a1d8a6e671b = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_2fa1c315825c19b1f5018415970a3a30 = $(`&lt;div id=&quot;html_2fa1c315825c19b1f5018415970a3a30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&l

# %% [markdown]
# ### Circle Marker

# %%
import pandas as pd

data = [
    ('강남구', 37.5172, 127.0473, 564000),
    ('서초구', 37.4837, 127.0324, 444000),
    ('종로구', 37.5730, 126.9794, 153000),
    ('송파구', 37.5145, 127.1058, 671000),
    ('강서구', 37.5509, 126.8495, 588000),
    ('노원구', 37.6541, 127.0568, 514000),
]
df = pd.DataFrame(data, columns=['구', '위도', '경도', '인구'])

m3 = folium.Map(location=[37.566, 126.978], zoom_start=11)

for _, row in df.iterrows():
    folium.CircleMarker(
        location=[row['위도'], row['경도']],
        radius=row['인구'] / 20000,
        color='crimson',
        fill=True,
        fill_color='crimson',
        fill_opacity=0.5,
        tooltip=f"{row['구']}: {row['인구']:,}명"
    ).add_to(m3)

m3.save('data/map_circle.html')
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9dee32ad966cda9c851f10cf37818c9d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9dee32ad966cda9c851f10cf37818c9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9dee32ad966cda9c851f10cf37818c9d = L.map(
#                 &quot;map_9dee32ad966cda9c851f10cf37818c9d&quot;,
#                 {
#                     center: [37.566, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b35b5294f09b1088892296b68a6530a3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b35b5294f09b1088892296b68a6530a3.addTo(map_9dee32ad966cda9c851f10cf37818c9d);
#
#
#             var circle_marker_80fdaa9729579e61a54eefc5730f2f1f = L.circleMarker(
#                 [37.5172, 127.0473],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 28.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9dee32ad966cda9c851f10cf37818c9d);
#
#
#             circle_marker_80fdaa9729579e61a54eefc5730f2f1f.bindTooltip(
#                 `&lt;div&gt;
#                      강남구: 564,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_e5da947fcce52622292254bc3a870d9a = L.circleMarker(
#                 [37.4837, 127.0324],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9dee32ad966cda9c851f10cf37818c9d);
#
#
#             circle_marker_e5da947fcce52622292254bc3a870d9a.bindTooltip(
#                 `&lt;div&gt;
#                      서초구: 444,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_78e01170625c7af6b9e85610a7e9c28d = L.circleMarker(
#                 [37.573, 126.9794],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.65, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9dee32ad966cda9c851f10cf37818c9d);
#
#
#             circle_marker_78e01170625c7af6b9e85610a7e9c28d.bindTooltip(
#                 `&lt;div&gt;
#                      종로구: 153,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_7d50571356d553d6ff01d7e908795716 = L.circleMarker(
#                 [37.5145, 127.1058],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 33.55, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9dee32ad966cda9c851f10cf37818c9d);
#
#
#             circle_marker_7d50571356d553d6ff01d7e908795716.bindTooltip(
#                 `&lt;div&gt;
#                      송파구: 671,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_2b447863fdf2ec47376c6a21d5360835 = L.circleMarker(
#                 [37.5509, 126.8495],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArr

# %% [markdown]
# ### 지하철 2호선 혼잡도 히트맵

# %%
import folium
from folium.plugins import HeatMap

line2_stations = [
    ('강남', 37.4979, 127.0276, 200000),
    ('홍대입구', 37.5572, 126.9249, 190000),
    ('신촌', 37.5553, 126.9364, 160000),
    ('신림', 37.4846, 126.9290, 175000),
    ('구로디지털단지', 37.4854, 126.9012, 140000),
    ('잠실', 37.5133, 127.1001, 210000),
    ('왕십리', 37.5613, 127.0375, 130000),
    ('성수', 37.5445, 127.0556, 120000),
    ('서울대입구', 37.4812, 126.9528, 145000),
    ('사당', 37.4763, 126.9817, 180000),
]

m_heat = folium.Map(location=[37.530, 126.990], zoom_start=12)

# 히트맵 데이터: [위도, 경도, 가중치]
heat_data = [[s[1], s[2], s[3] / 210000] for s in line2_stations]

HeatMap(heat_data, radius=30, blur=20, max_zoom=13).add_to(m_heat)

# 역명 마커 추가
for name, lat, lon, cnt in line2_stations:
    folium.CircleMarker(
        location=[lat, lon], radius=6,
        color='darkblue', fill=True, fill_color='white',
        tooltip=f'{name}: {cnt:,}명'
    ).add_to(m_heat)

m_heat.save('data/map_subway_heat.html')
m_heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa596b026f8afcdb829c27924b5af4e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa596b026f8afcdb829c27924b5af4e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa596b026f8afcdb829c27924b5af4e5 = L.map(
#                 &quot;map_fa596b026f8afcdb829c27924b5af4e5&quot;,
#                 {
#                     center: [37.53, 126.99],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_795348b2c060712deb50c2cc1e52f4f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_795348b2c060712deb50c2cc1e52f4f7.addTo(map_fa596b026f8afcdb829c27924b5af4e5);
#
#
#             var heat_map_3633385f50c5e4dd1f0533d0fa884579 = L.heatLayer(
#                 [[37.4979, 127.0276, 0.9523809523809523], [37.5572, 126.9249, 0.9047619047619048], [37.5553, 126.9364, 0.7619047619047619], [37.4846, 126.929, 0.8333333333333334], [37.4854, 126.9012, 0.6666666666666666], [37.5133, 127.1001, 1.0], [37.5613, 127.0375, 0.6190476190476191], [37.5445, 127.0556, 0.5714285714285714], [37.4812, 126.9528, 0.6904761904761905], [37.4763, 126.9817, 0.8571428571428571]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 13,
#   &quot;radius&quot;: 30,
#   &quot;blur&quot;: 20,
# }
#             );
#
#
#             heat_map_3633385f50c5e4dd1f0533d0fa884579.addTo(map_fa596b026f8afcdb829c27924b5af4e5);
#
#
#             var circle_marker_3a29927a8df317100b8e30b14f32b783 = L.circleMarker(
#                 [37.4979, 127.0276],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fa596b026f8afcdb829c27924b5af4e5);
#
#
#             circle_marker_3a29927a8df317100b8e30b14f32b783.bindTooltip(
#                 `&lt;div&gt;
#                      강남: 200,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ede5302883e6b7e9bbbbb9fc0fa4a548 = L.circleMarker(
#                 [37.5572, 126.9249],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fa596b026f8afcdb829c27924b5af4e5);
#
#
#             circle_marker_ede5302883e6b7e9bbbbb9fc0fa4a548.bindTooltip(
#                 `&lt;div&gt;
#                      홍대입구: 190,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_e2b12845f9b8d3d83f01d395c8314241 = L.circleMarker(
#                 [37.5553, 126.9364],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fa596b026f8afcdb829c27924b5af4e5);
#
#
#             circle_marker_e2b12845f9b8d3d83f01d395c8314241.bindTooltip(
#                 `&lt;div&gt;
#                      신촌: 160,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_2119b5805cecd8c92fcd77fa0dab35a9 = L.circleMarker(
#                 [37.4846, 126.929],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dash

# %% [markdown]
# ### 따릉이 대여소 위치 표시 - 자치구별 거치대수 많은 기준 대여소 1개씩

# %%
import pandas as pd
import folium

df = pd.read_excel('data/공공자전거 대여소 정보(25.12월 기준).xlsx', header=None)
df.head(10)
df_bike = df.iloc[5:, [1, 2, 4, 5, 8]]
df_bike.head()
# Out:
#              1    2          4           5   8
# 5   망원역 1번출구 앞  마포구  37.555649  126.910629  15
# 6   망원역 2번출구 앞  마포구  37.554951  126.910835  14
# 7   합정역 1번출구 앞  마포구  37.550629  126.914986  13
# 8   합정역 5번출구 앞  마포구  37.550007  126.914825   5
# 9   합정역 7번출구 앞  마포구  37.548645  126.912827  12

# %%
# 컬럼명 수정
df_bike.columns = ['대여소명', '자치구','위도', '경도', '거치대수']
df_bike.head()
# Out:
#           대여소명  자치구         위도          경도 거치대수
# 5   망원역 1번출구 앞  마포구  37.555649  126.910629   15
# 6   망원역 2번출구 앞  마포구  37.554951  126.910835   14
# 7   합정역 1번출구 앞  마포구  37.550629  126.914986   13
# 8   합정역 5번출구 앞  마포구  37.550007  126.914825    5
# 9   합정역 7번출구 앞  마포구  37.548645  126.912827   12

# %%
# 자치구별 거치대수가 가장 많은 대여소 필터
st = df_bike.loc[ df_bike.groupby('자치구')['거치대수'].sum()]
st['위도'] = st['위도'].astype(float)
st['경도'] = st['경도'].astype(float)
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 907 to 517
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소명    25 non-null     object
#  1   자치구     25 non-null     object
#  2   위도      25 non-null     float64
#  3   경도      25 non-null     float64
#  4   거치대수    9 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 1.2+ KB

# %%
# 지도 생성
m_bike = folium.Map(location=[37.530, 126.990], zoom_start=12)

# %%
# 마커 생성
for idx, row in st.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=row['대여소명'],
        tooltip=row['대여소명']
    ).add_to(m_bike)

m_bike.save('data/map_bike.html')
m_bike
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_992517e465506683c0dc95b2c416be58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_992517e465506683c0dc95b2c416be58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_992517e465506683c0dc95b2c416be58 = L.map(
#                 &quot;map_992517e465506683c0dc95b2c416be58&quot;,
#                 {
#                     center: [37.53, 126.99],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c19eee27381218fd4cb933d7a4954a4a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c19eee27381218fd4cb933d7a4954a4a.addTo(map_992517e465506683c0dc95b2c416be58);
#
#
#             var marker_6660daa86407be3e38ddb52afed84518 = L.marker(
#                 [37.61052322, 127.05979919],
#                 {
# }
#             ).addTo(map_992517e465506683c0dc95b2c416be58);
#
#
#         var popup_fa234d135f7142a7ec9a0616ebd4a353 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07a6b891a22da276151d33bca9b0645f = $(`&lt;div id=&quot;html_07a6b891a22da276151d33bca9b0645f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; 석관초등학교 앞&lt;/div&gt;`)[0];
#                 popup_fa234d135f7142a7ec9a0616ebd4a353.setContent(html_07a6b891a22da276151d33bca9b0645f);
#
#
#
#         marker_6660daa86407be3e38ddb52afed84518.bindPopup(popup_fa234d135f7142a7ec9a0616ebd4a353)
#         ;
#
#
#
#
#             marker_6660daa86407be3e38ddb52afed84518.bindTooltip(
#                 `&lt;div&gt;
#                       석관초등학교 앞
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_83b0929f2294a8d01405dc2e62e8c0e6 = L.marker(
#                 [37.58932877, 127.01643372],
#                 {
# }
#             ).addTo(map_992517e465506683c0dc95b2c416be58);
#
#
#         var popup_74850fd2d71207789708bd9a0e478137 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d89de1851f663d0ae4203d32ff6fe72 = $(`&lt;div id=&quot;html_3d89de1851f663d0ae4203d32ff6fe72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; 성북구청&lt;/div&gt;`)[0];
#                 popup_74850fd2d71207789708bd9a0e478137.setContent(html_3d89de1851f663d0ae4203d32ff6fe72);
#
#
#
#         marker_83b0929f2294a8d01405dc2e62e8c0e6.bindPopup(popup_74850fd2d71207789708bd9a0e478137)
#         ;
#
#
#
#
#             marker_83b0929f2294a8d01405dc2e62e8c0e6.bindTooltip(
#                 `&lt;div&gt;
#                       성북구청
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_8c53bdee73cb4a10be4980b42dcf9f9c = L.marker(
#                 [37.57048035, 126.99663544],
#                 {
# }
#             ).addTo(map_992517e465506683c0dc95b2c416be58);
#
#
#         var popup_886dce587ef7b28644ab3443f6bc2b9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ac3f55ecafd87f6532deeb9cd8b1cb1 = $(`&lt;div id=&quot;html_0ac3f55ecafd87f6532deeb9cd8b1cb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; 종묘공영주차장 건너편&lt;/div&gt;`)[0];
#                 popup_886dce587ef7b28644ab3443f6bc2b9b.setContent(html_0ac3f55ecafd87f6532deeb9cd8b1cb1);
#
#
#
#         marker_8c53bdee73cb4a10be4980b42dcf9f9c.bindPopup(popup_886dce587ef7b28644ab3443f6bc2b9b)
#         ;
#
#
#
#
#             marker_8c53bdee73cb4a10be4980b42dcf9f9c.bindTooltip(
#                 `&lt;div&gt;
#                       종묘공영주차장 건너편
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f28d6796db99ad4cd9f1aeaeac7fa266 = L.marker(
#                 [37.674366, 127.05947113],
#                 {
# }
#             ).addTo(map_992517e465506683c0dc95b2c416be58);
#
#
#         var popup_f62bc3d7ca78ebafeb6691d85519d7cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37905d875d6fc6df5cf3290bbe9bee45 = $(`&lt;div id=&quot;html_37905d875d6fc6df5cf3290bbe9bee45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; 휴플러스 수락한신아파트 101동 앞&lt;/div&gt;`)[0];
#                 popup_f62bc3d7ca78ebafeb6691d85519d7cf.setContent(html_37905d875d6fc6df5cf3290bbe9bee45);
#
#
#
#         marker_f28d6796db99ad4cd9f1aeaeac7fa266.bindPopup(popup_f62bc3d7ca78ebafeb6691d85519d7cf)
#         ;
