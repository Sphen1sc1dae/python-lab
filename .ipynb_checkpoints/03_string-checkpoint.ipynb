# %% [markdown]
# # 문자열
# - 문자열 : 파이썬에서는 따옴표(' ', " ")로 둘러싼 문자 집합을 의미

# %% [markdown]
# ## 1. 문자열 생성

# %% [markdown]
# - 시작과 끝에 같은 따옴표를 사용한다. 예) " ~ " , ' ~ '

# %%
print('Hello ~ Python')
# Out:
# Hello ~ Python

# %%
print("Hello ~ Python")
# Out:
# Hello ~ Python

# %%
print('Hello ~ Python") # 시작과 끝 다르면 에러
# Out:
#   Cell In[4], line 1
#     print('Hello ~ Python")
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
str1 = 'Hello~ Python'
str2 = "Hello~ Python"
print(str1, str2)
# Out:
# Hello~ Python Hello~ Python

# %%
type(str1)
# Out:
# str

# %%
print(type(str1), type(str2))
# Out:
# <class 'str'> <class 'str'>

# %%
# 제 이름은 '홍길동' 입니다
str3 = "제 이름은 '홍길동' 입니다"
print(str3)
# Out:
# 제 이름은 '홍길동' 입니다

# %%
# 제 이름은 '홍길동' 입니다
str3 = '제 이름은 '홍길동' 입니다' # 오류 발생
print(str3)

# %%
# 문자열을 여러 줄 입력하는 방법 - """ ... """ 또는 ''' ... '''
str4 = """파이썬을
배우는
중입니다."""
print(str4)
# Out:
# 파이썬을
# 배우는
# 중입니다.

# %% [markdown]
# ## 2. 문자열 다루기
# - 더하기 연산자(+) 와 곱하기 연산자(*) 이용
#   - (+) 연산자 : 문자열 결합(concatenation)을 통해 하나로 생성함
#   - (*) 연산자 : 횟수만큼 문자열 반복

# %%
a = 'hello~'
b = 'python'
c = a + b
print(c)
# Out:
# hello~python

# %%
a * 3 + b * 3
# Out:
# 'hello~hello~hello~pythonpythonpython'

# %%
a + b * 3
# Out:
# 'hello~pythonpythonpython'

# %%
(a + b) * 3
# Out:
# 'hello~pythonhello~pythonhello~python'

# %%
c * 3
# Out:
# 'hello~pythonhello~pythonhello~python'

# %%
print(a)
print(b)
print('-' * 30)
print(c)
# Out:
# hello~
# python
# ------------------------------
# hello~python
